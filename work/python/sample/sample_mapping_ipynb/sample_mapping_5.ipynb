# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# 2019年4月の休日昼間人口を地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='geom') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = "SELECT p.name, d.prefcode, d.year, d.month, d.population, p.geom \
        FROM pop AS d \
            INNER JOIN pop_mesh AS p \
                ON p.name = d.mesh1kmid \
            WHERE d.dayflag='0' AND \
                d.timezone='0' AND \
                d.year='2019' AND \
                d.month='04'"

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    m = folium.Map(location=[36, 139.5], zoom_start=8)

    # Add the choropleth layer
    folium.Choropleth(
        geo_data=gdf.to_json(),
        data=gdf,
        columns=['name', 'population'],
        key_on='feature.properties.name',
        fill_color='YlOrRd',
        fill_opacity=0.7,
        line_opacity=0,
        bins=[0, 1000, 5000, 10000, 25000, 50000, 75000, 100000, 140000]
    ).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
print(out)

map_display = display_interactive_map(out)

display(map_display)
# Out:
#            name prefcode  year month  population  \
# 0      53404026       12  2020    04      3780.0
# 1      53402099       12  2020    04      3367.0
# 2      53403088       12  2020    04      4589.0
# 3      53402143       12  2020    04      3752.0
# 4      53397722       12  2020    04      1840.0
# ...         ...      ...   ...   ...         ...
# 20330  53394473       13  2020    04     22139.0
# 20331  53395173       13  2020    04       610.0
# 20332  53395181       13  2020    04       104.0
# 20333  51394241       13  2020    04       243.0
# 20334  49394692       13  2020    04        11.0
#
#                                                     geom
# 0      MULTIPOLYGON (((140.075 35.68333, 140.075 35.6...
# 1      MULTIPOLYGON (((140.1125 35.575, 140.1125 35.5...
# 2      MULTIPOLYGON (((140.1 35.65, 140.1 35.65833, 1...
# 3      MULTIPOLYGON (((140.1625 35.53333, 140.1625 35...
# 4      MULTIPOLYGON (((139.9 35.93333, 139.9 35.94167...
# ...                                                  ...
# 20330  MULTIPOLYGON (((139.5375 35.725, 139.5375 35.7...
# 20331  MULTIPOLYGON (((139.1625 35.80833, 139.1625 35...
# 20332  MULTIPOLYGON (((139.1375 35.81667, 139.1375 35...
# 20333  MULTIPOLYGON (((139.2625 34.36667, 139.2625 34...
# 20334  MULTIPOLYGON (((139.775 33.075, 139.775 33.083...
#
# [20335 rows x 6 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 out = query_geopandas(sql,'gisdb')
#       2 print(out)
# ----> 4 map_display = display_interactive_map(out)
#       6 display(map_display)
#
# Cell In[4], line 5, in display_interactive_map(gdf)
#       2 m = folium.Map(location=[36, 139.5], zoom_start=8)
#       4 # Add the choropleth layer
# ----> 5 folium.Choropleth(
#       6     geo_data=gdf.to_json(),
#       7     data=gdf,
#       8     columns=['name', 'population'],
#       9     key_on='feature.properties.name',
#      10     fill_color='YlOrRd',
#      11     fill_opacity=0.7,
#      12     line_opacity=0,
#      13     bins=[0, 1000, 5000, 10000, 25000, 50000, 75000, 100000, 140000]
#      14 ).add_to(m)
#      16 return m
#
# File /usr/local/lib/python3.11/site-packages/folium/features.py:1574, in Choropleth.__init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1572 bins_min, bins_max = min(bin_edges), max(bin_edges)
#    1573 if np.any((real_values < bins_min) | (real_values > bins_max)):
# -> 1574     raise ValueError(
#    1575         "All values are expected to fall into one of the provided "
#    1576         "bins (or to be Nan). Please check the `bins` parameter "
#    1577         "and/or your data."
#    1578     )
#    1580 # We add the colorscale
#    1581 nb_bins = len(bin_edges) - 1
#
# ValueError: All values are expected to fall into one of the provided bins (or to be Nan). Please check the `bins` parameter and/or your data.
