# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# ## Task

# %% [markdown]
# さいたま県内でお酒を飲めるお店を地図上に表す

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.amenity in ('bar','biergarten','pub') and
    poly.name_1 IN ('Saitama') and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#           osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0     5966331972   None           None             None               None
# 1     5966331982   None           None             None               None
# 2     8069331364   None           None             None               None
# 3     7429430393   None           None               3号               None
# 4     7428218196   None           None             None               None
# ..           ...    ...            ...              ...                ...
# 786   9952036660   None           None             None               None
# 787   9952036659   None           None             None               None
# 788  12540923336   None           None             None               None
# 789   7652516444   None           None             None               None
# 790   3127816595   None           None             None               None
#
#     admin_level aerialway aeroway amenity  area barrier bicycle brand bridge  \
# 0          None      None    None     bar  None    None    None  None   None
# 1          None      None    None     pub  None    None    None  None   None
# 2          None      None    None     pub  None    None    None  None   None
# 3          None      None    None     pub  None    None    None  None   None
# 4          None      None    None     bar  None    None    None  None   None
# ..          ...       ...     ...     ...   ...     ...     ...   ...    ...
# 786        None      None    None     bar  None    None    None  None   None
# 787        None      None    None     pub  None    None    None  None   None
# 788        None      None    None     pub  None    None    None  None   None
# 789        None      None    None     pub  None    None    None  None   None
# 1       None  None    None  None  None    None  None    None       None
# 2       None  None    None  None  None    None  None    None       None
# 3       None  None    None  None  None    None  None    None       None
# 4       None  None    None  None  None    None  None    None       None
# ..       ...   ...     ...   ...   ...     ...   ...     ...        ...
# 786     None  None    None  None  None    None  None    None       None
# 787     None  None    None  None  None    None  None    None       None
# 788     None  None    None  None  None    None  None    None       None
# 789     None  None    None  None  None    None  None    None       None
# 790     None  None    None  None  None    None  None    None       None
#
#     tunnel water waterway wetland width  wood z_order  \
# 0     None  None     None    None  None  None    None
# 1     None  None     None    None  None  None    None
# 2     None  None     None    None  None  None    None
# 3     None  None     None    None  None  None    None
# 4     None  None     None    None  None  None    None
# ..     ...   ...      ...     ...   ...   ...     ...
# 786   None  None     None    None  None  None    None
# 787   None  None     None    None  None  None    None
# 788   None  None     None    None  None  None    None
# 789   None  None     None    None  None  None    None
# 790   None  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15535660.805 4294053.996)
# 1    POINT (15535687.455 4293989.611)
# 2     POINT (15539026.45 4295556.605)
# 3    POINT (15540737.853 4300946.164)
# 4    POINT (15540383.802 4301497.552)
# ..                                ...
# 786  POINT (15566037.901 4272273.928)
# 787  POINT (15566042.877 4272276.261)
# 788  POINT (15567154.146 4275831.599)
# 789  POINT (15567272.735 4274144.427)
# 790  POINT (15567386.248 4283587.937)
#
# [791 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d95c2aa845c5e93fca9f20e1ac2ce9a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d95c2aa845c5e93fca9f20e1ac2ce9a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d95c2aa845c5e93fca9f20e1ac2ce9a9 = L.map(
#                 &quot;map_d95c2aa845c5e93fca9f20e1ac2ce9a9&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8239c40c7a5cdbd57703fff0dd9d1a55 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8239c40c7a5cdbd57703fff0dd9d1a55.addTo(map_d95c2aa845c5e93fca9f20e1ac2ce9a9);
#
#
#             var marker_e9c2da123ef50a846a3add144ff6fb43 = L.marker(
#                 [35.95225699973082, 139.55921549999997],
#                 {
# }
#             ).addTo(map_d95c2aa845c5e93fca9f20e1ac2ce9a9);
#
#
#         var popup_914634d96bb42d7317278ac6ce4526ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f82e7dbc853476bf1088a018b85332d4 = $(`&lt;div id=&quot;html_f82e7dbc853476bf1088a018b85332d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;シャンテ&lt;/div&gt;`)[0];
#                 popup_914634d96bb42d7317278ac6ce4526ae.setContent(html_f82e7dbc853476bf1088a018b85332d4);
#
#
#
#         marker_e9c2da123ef50a846a3add144ff6fb43.bindPopup(popup_914634d96bb42d7317278ac6ce4526ae)
#         ;
#
#
#
#
#             var marker_3d93bb4c9cabfd7a7b380a81f00f01f0 = L.marker(
#                 [35.95178879973078, 139.5594549],
#                 {
# }
#             ).addTo(map_d95c2aa845c5e93fca9f20e1ac2ce9a9);
#
#
#         var popup_6539d4b4fd978f789851f74b9f68cd21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69689df2285637d9559e443052570d44 = $(`&lt;div id=&quot;html_69689df2285637d9559e443052570d44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;十八番&lt;/div&gt;`)[0];
#                 popup_6539d4b4fd978f789851f74b9f68cd21.setContent(html_69689df2285637d9559e443052570d44);
#
#
#
#         marker_3d93bb4c9cabfd7a7b380a81f00f01f0.bindPopup(popup_6539d4b4fd978f789851f74b9f68cd21)
#         ;
#
#
#
#
#             var marker_3393b26bb05335be41350f4992c073f7 = L.marker(
#                 [35.96318309973189, 139.5894496],
#                 {
# }
#             ).addTo(map_d95c2aa845c5e93fca9f20e1ac2ce9a9);
#
#
#         var popup_865b1f70f339063980308a4a5d960525 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ea41288817e3628734ed35e69f44125 = $(`&lt;div id=&quot;html_1ea41288817e3628734ed35e69f44125&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;居酒屋ぽぽん太&lt;/div&gt;`)[0];
#                 popup_865b1f70f339063980308a4a5d960525.setContent(html_1ea41288817e3628734ed35e69f44125);
#
#
#
#         marker_3393b26bb05335be41350f4992c073f7.bindPopup(popup_865b1f70f339063980308a4a5d960525)
#         ;
#
#
#
#
#             var marker_b1bdd60ec79be2dc6c1008889518f07b = L.marker(
#                 [36.002360399735764, 139.60482339999996],
#                 {
# }
#             ).addTo(map_d95c2aa845c5e93fca9f20e1ac2ce9a9);
#
#
#         var popup_9f6b4cb87dcd7acf732f1c17727d76da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45b757c9da6aed69b04a77b704fe7855 = $(`&lt;div id=&quot;html_45b757c9da6aed69b04a77b704fe7855&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;いなかっぺ&lt;/div&gt;`)[0];
#                 popup_9f6b4cb87dcd7acf732f1c17727d76da.setContent(html_45b757c9da6aed69b04a77b704fe7855);
#
#
#
#         marker_b1bdd60ec79be2dc6c1008889518f07b.bindPopup(popup_9f6b4cb87dcd7acf732f1c17727d76da)
#         ;
#
#
#
#
#             var marker_6ef24ad71d8805127924eb7d2f1ee754 = L.marker(
#                 [36.006367399736185, 139.6016429],
#                 {
# }
#             ).addTo(map_d95c2aa845c5e93fca9f20e1ac2ce9a9);
#
#
#         var popup_77ee1e5a00d36393ecd648e8b0b322df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bea6e248247c703e486507a95d95d598 = $(`&lt;div id=&quot;html_bea6e248247c703e486507a95d95d598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;アポロ&lt;/div&gt;`)[0];
#                 popup_77ee1e5a00d36393ecd648e8b0b322df.setContent(html_bea6e248247c703e486507a95d95d598);
#
#
#
#         marker_6ef24ad71d8805127924eb7d2f1ee754.bindPopup(popup_77ee1e5a00d36393ecd648e8b0b322df)
#         ;
#
#
#
#
#             var marker_418c5016dba02119796e26de6d4c12b0 = L.marker(
#                 [35.953568699730944
