# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
pd.set_option('display.max_columns', 20)

# %%
def query_pandas(sql, db):
    """
    Executes a SQL query on a PostgreSQL database and returns the result as a Pandas DataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        pandas.DataFrame: The result of the SQL query as a Pandas DataFrame.
    """

    DATABASE_URL='postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)

    df = pd.read_sql(sql=sql, con=conn)

    return df

# %% [markdown]
# ## Define a sql command

# %%
sql =   "WITH \
            pop_202004 AS ( \
                SELECT p.name, d.prefcode, d.year, d.month, d.population, p.geom \
                FROM pop AS d \
                INNER JOIN pop_mesh AS p \
                    ON p.name = d.mesh1kmid \
                WHERE d.dayflag='0' AND \
                    d.timezone='0' AND \
                    d.year='2020' AND \
                    d.month='04' \
            ), \
            pop_201904 AS ( \
                SELECT p.name, d.prefcode, d.year, d.month, d.population, p.geom \
                FROM pop AS d \
                INNER JOIN pop_mesh AS p \
                    ON p.name = d.mesh1kmid \
                WHERE d.dayflag='0' AND \
                    d.timezone='0' AND \
                    d.year='2019' AND \
                    d.month='04' \
            ), \
            station_area AS ( \
                SELECT pt.osm_id, pt.name, poly2.name_1, ST_BUFFER(ST_Transform(pt.way, 4326)::geography, 300)::geometry AS geom\
                from planet_osm_point pt, adm2 poly2 \
                where pt.railway='station' and \
                st_intersects(pt.way,ST_TRANSFORM(poly2.geom,3857))\
            ), \
            station_pop_202004 AS ( \
                SELECT s.name, s.name_1, SUM(p.population * ST_AREA(ST_INTERSECTION(s.geom::geography,p.geom::geography)) / ST_AREA(p.geom::geography)) as population_r300 \
                FROM station_area AS s \
                INNER JOIN pop_202004 AS p ON ST_INTERSECTS(s.geom,p.geom) \
                GROUP BY s.name, s.name_1 \
                ORDER BY population_r300 DESC \
            ), \
            station_pop_201904 AS ( \
                SELECT s.name, s.name_1, SUM(p.population * ST_AREA(ST_INTERSECTION(s.geom::geography,p.geom::geography)) / ST_AREA(p.geom::geography)) as population_r300 \
                FROM station_area AS s \
                INNER JOIN pop_201904 AS p ON ST_INTERSECTS(s.geom,p.geom) \
                GROUP BY s.name, s.name_1 \
                ORDER BY population_r300 DESC \
            ), \
            station_cp AS ( \
                SELECT sp_202004.name_1, sp_202004.name, (sp_202004.population_r300 - sp_201904.population_r300) / sp_201904.population_r300 AS cp_rate \
                FROM station_pop_202004 AS sp_202004 \
                INNER JOIN station_pop_201904 AS sp_201904 ON sp_202004.name=sp_201904.name AND sp_202004.name_1=sp_201904.name_1 \
                ORDER BY sp_202004.name_1 DESC \
            ), \
            min_cp AS ( \
                SELECT s.name_1, MIN(s.cp_rate) AS min_cp_rate \
                FROM station_cp AS s GROUP BY s.name_1 \
            ) \
        SELECT s.name_1, s.name, s.cp_rate AS min_cp_rate \
            FROM station_cp AS s \
            INNER JOIN min_cp AS m ON s.name_1=m.name_1 AND s.cp_rate=m.min_cp_rate \
            ORDER BY name_1"

# %% [markdown]
# ## Outputs

# %%
out = query_pandas(sql,'gisdb')
print(out)
# Out:
#      name_1               name  min_cp_rate
# 0     Chiba                 西畑    -0.875315
# 1     Gunma                雁ヶ沢    -0.758960
# 2   Ibaraki               筑波山頂    -0.869996
# 3  Kanagawa             ダム上 山頂    -0.810352
# 4   Saitama                三峰口    -0.901277
# 5   Tochigi               男鹿高原    -0.993503
# 6     Tokyo  ポートディスカバリー・ステーション    -0.979896
